# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)

# import os
# from dotenv import load_dotenv

# load_dotenv()

# import kagglehub
# from kagglehub import KaggleDatasetAdapter

# print("Username set:", bool(os.getenv("KAGGLE_USERNAME")))
# print("Key set:", bool(os.getenv("KAGGLE_KEY")))
# print("Cache dir:", os.getenv("KAGGLEHUB_CACHE"))

# # Downloads (with progress bar) into your custom folder
# path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
# print("Downloaded to:", path)

# # Load into pandas
# file_path = "creditcard.csv"
# df = kagglehub.load_dataset(
#     KaggleDatasetAdapter.PANDAS,
#     "mlg-ulb/creditcardfraud",
#     file_path,
# )

# print("First 5 records:")
# print(df.head())
# Out:
# ...
# 100%|██████████| 66.0M/66.0M [00:07<00:00, 9.64MB/s]
# Extracting files...
# Path to dataset files: D:/Project/creditcard-fraud-detection-proj/data\datasets\mlg-ulb\creditcardfraud\versions\3

# %%
from pathlib import Path
print(Path(path).as_posix())
# Out:
# D:/Project/creditcard-fraud-detection-proj/data/datasets/mlg-ulb/creditcardfraud/versions/3

# %%
import os
from dotenv import load_dotenv
load_dotenv()

print("Username set:", bool(os.getenv("KAGGLE_USERNAME")))
print("Key set:", bool(os.getenv("KAGGLE_KEY")))

import kagglehub
# This downloads to a local cache and shows a progress bar —
# separate from load_dataset, so you can see if it's actually moving
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
print("Downloaded to:", path)
